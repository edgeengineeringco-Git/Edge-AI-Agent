# %%
import torch
print('CUDA available:', torch.cuda.is_available())
print('device count:', torch.cuda.device_count())
print('torch:', torch.__version__)
# !echo '--- github curl ---'; curl -sS --max-time 15 -o /dev/null -w 'HTTP %{http_code}\n' https://github.com || echo 'curl failed rc=$?'
# !echo '--- dns ---'; getent hosts github.com || echo 'no DNS for github.com'
# !echo '--- pip index test ---'; curl -sS --max-time 15 -o /dev/null -w 'pypi HTTP %{http_code}\n' https://pypi.org/simple/ || echo 'pypi failed'
