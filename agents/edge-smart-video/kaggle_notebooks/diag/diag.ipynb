# %%
# !curl -sI --max-time 20 https://github.com | head -3
# !curl -sI --max-time 20 https://pypi.org | head -3
# !python -c "import torch; print('torch', torch.__version__)"
# !python -c "import face_alignment; print('face_alignment OK')" 2>&1 | head -2
# !pip list 2>/dev/null | grep -iE 'sadtalker|basicsr|gfpgan|facexlib|kornia' | head
